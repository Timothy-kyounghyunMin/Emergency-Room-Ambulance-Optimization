# %%
#########################################################
# Import Several Packages
#########################################################
from math import *
from tqdm.notebook import tqdm
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.animation import FuncAnimation
import seaborn as sns
import warnings
import json
import sys
import queue

warnings.filterwarnings(action='ignore')

seed_num = 2


# Set Random Seed
np.random.seed(seed_num)


#########################################################
# 구현해야 하는 기본 모듈: map / patient / hospital

#########################################################
######################## For MAP ########################
#########################################################
"""
[ Attributes] 

1. GRID:
	- min_lat								(float)
    - max_lat								(float)
    - min_lon								(float)
    - max_lon								(float)
2. districts: 								(dict)
	{0:[center_location, radius], ...}
    - 0: 관악구
    - center_location: mu_1, mu_2 			(tuple)
    - radius: np.sqrt(size/np.pi) 			(float)
3. weights: 								(list)
	[관악구 인구 %, 그 외 다른 거 %, ]
4. patient_dict:							(dict)
	{id: class Patient(), ...}
5. acc_patient_num:							(int)

[ Methods ]

1. create_patient(self, no arg)				(func)
	- id = self.acc_patient_num
    - d_id = np.random.choice(self.weights)
      lat, lon = np.random.multivariatenormal(self.districts[d_id][0], self.districts[d_id][0])
      lat = max(min(lat, max_lat), min_lat)
      lon = max(min(lon, max_lon), min_lon)
      location = (lat, lon)
    - created_time = tau
    - state = 0
    - destiny = np.random."oracle"
      (oracle: 처음에는 사망 확률이 낮다가, 시간 지나면 상승, left skewed)			[GPT 부탁해!]
    
    (그래서)
    self.patient_dict[id] = Patient(id, location, created_time, state, destiny)
    
    return
"""
# Out:
# '\n[ Attributes] \n\n1. GRID:\n\t- min_lat\t\t\t\t\t\t\t\t(float)\n    - max_lat\t\t\t\t\t\t\t\t(float)\n    - min_lon\t\t\t\t\t\t\t\t(float)\n    - max_lon\t\t\t\t\t\t\t\t(float)\n2. districts: \t\t\t\t\t\t\t\t(dict)\n\t{0:[center_location, radius], ...}\n    - 0: 관악구\n    - center_location: mu_1, mu_2 \t\t\t(tuple)\n    - radius: np.sqrt(size/np.pi) \t\t\t(float)\n3. weights: \t\t\t\t\t\t\t\t(list)\n\t[관악구 인구 %, 그 외 다른 거 %, ]\n4. patient_dict:\t\t\t\t\t\t\t(dict)\n\t{id: class Patient(), ...}\n5. acc_patient_num:\t\t\t\t\t\t\t(int)\n\n[ Methods ]\n\n1. create_patient(self, no arg)\t\t\t\t(func)\n\t- id = self.acc_patient_num\n    - d_id = np.random.choice(self.weights)\n      lat, lon = np.random.multivariatenormal(self.districts[d_id][0], self.districts[d_id][0])\n      lat = max(min(lat, max_lat), min_lat)\n      lon = max(min(lon, max_lon), min_lon)\n      location = (lat, lon)\n    - created_time = tau\n    - state = 0\n    - destiny = np.random."oracle"\n      (oracle: 처음에는 사망 확률이 낮다가, 시간 지나면 상승, left skewed)\t\t\t[GPT 부탁해!]\n    \n    (그래서)\n    self.patient_dict[id] = Patient(id, location, created_time, state, destiny)\n    \n    return\n'

# %%
# Define Classes: Patient, Hospital

class Patient():
  def __init__(self, id:int, location:tuple, created_time:int, destiny:float):
    self.id = id
    self.location = location   #tuple (float, float)
    self.created_time = created_time
    self.destiny = destiny # 사망 시간
    self.decision = None # Optimizer에서 결정되어 할당 (향하고 있는 병원)
    self.treatment_time = None # Optimizer에서 결정되어 할당 (치료 시간)

    
class Hospital():
  def __init__(self, hospitals_id:int, hospitals_location:tuple, mean_treat_time:int):
    self.queue = [] # queue.Queue()
    self.len_queue = 0
    self.treat_start = None
    self.id = hospitals_id
    self.location = hospitals_location
    self.mean_treat_time = mean_treat_time
  
  def sample_treat_time(self):
    np.random.seed(seed_num)
    treat_time = np.random.exponential(self.mean_treat_time, 1)
    return treat_time

# %%
def create_patient(model_type: str, patient_location, patient_district, patient_destiny):
    """
    model_type: 'naive' or 'opt'
    """
    global tau, acc_patient_num, weights, districts, GRID 
    
    id = acc_patient_num
    created_time = tau # Global time step

    print("환자 {}가 생성되었습니다. 위치: {}, 생성 시간: {}, 사망 시간: {}".format(id, patient_location, created_time, patient_destiny))

    # Assuming Patient class is defined elsewhere
    patient_dict[id] = Patient(id, patient_location, created_time, patient_destiny)
    
    acc_patient_num += 1

    # Determine the hospital that the patient should go using optimizer
    if model_type == 'opt':
      patient_dict[id].decision, _ = optimizer(id)
    elif model_type == 'naive':
      patient_dict[id].decision = naive_optimizer(id)
    else:
      raise ValueError("model_type should be either 'opt' or 'naive'")
    
    ##test
    temp_eta, temp_etaw = compute_etaw(patient_dict[id], patient_dict[id].decision, tau)
    print("환자 {}의 eta: {}, etaw: {}".format(id, temp_eta, temp_etaw))

def compute_etaw(patient: Patient, hospital: Hospital, tau: int):
  patient_lon, patient_lat = patient.location
  hospital_lon, hospital_lat = hospital.location

  # Calculate the real distance using l2 norm
  distance = np.sqrt((patient_lat - hospital_lat)**2 + (patient_lon - hospital_lon)**2)  ## km
  eta = distance / 10 * 3600
  wait = (hospital.len_queue + np.sqrt(hospital.len_queue)) * hospital.mean_treat_time
  etaw = eta + wait
    
  return eta, etaw

def get_new_location(patient_location, hospital_location):
  patient_lon, patient_lat = patient_location
  hospital_lon, hospital_lat = hospital_location

  # Calculate the real distance using l2 norm
  distance = np.sqrt((patient_lat - hospital_lat)**2 + (patient_lon - hospital_lon)**2)  ## km
  #print("distance: {}".format(distance))
  distance_sec = 10 / 3600
  new_patient_lat = (patient_lat * (distance - distance_sec) + hospital_lat * distance_sec) / distance
  new_patient_lon = (patient_lon * (distance - distance_sec) + hospital_lon * distance_sec) / distance
  
  return (new_patient_lon, new_patient_lat)
  


  
def updater(model_type: str):  
  global patient_dict, hospitals_dict, tau, death_toll, treatment_toll, etaw_toll
  """
  환자의 현재 위치 업데이트 (V)
  환자가 향하는 병원 업데이트 (V)
  사망 여부 확인 업데이트 (V)
  병원 도착 여부 확인 업데이트 (V)
  각 병원의 queue 업데이트 (V)
  각 병원의 치료 완료한 환자 수 업데이트 (V)  
  """

  """
  model_type: 'naive' or 'opt'
  """

  death_list = []
  arrival_list = []

  for id in patient_dict.keys():
    #################################################################
    ############# Step 1: 환자가 향해야 하는 병원 업데이트 #############
    # 처음에 환자가 생성되면, 해당 환자가 향해야 하는 병원을 optimizer를 통해 결정 (앞에서)
    # 여기서는 모든 환자가 1분마다 업데이트를 통해, 환자가 향해야 하는 병원을 다시 결정

    patient_dict[id].location = get_new_location(patient_dict[id].location, patient_dict[id].decision.location) # 이동하고 있는 환자의 위치를 새로이 정의

    if model_type == 'opt':
      if tau % 60 == 0: # 1분마다 업데이트 (의사결정 주기)
        curr_opt_hospital, new_etaw = optimizer(id) # 현재 환자가 향해야 하는 병원을 새로이 정의
        if patient_dict[id].decision != curr_opt_hospital:
          print("Time", tau)
          print("환자 {}의 이동 경로가 변경되었습니다. from {} to {}".format(id, patient_dict[id].decision.id, curr_opt_hospital.id))
          print("환자 {}의 예상 etaw: {}".format(id, new_etaw))
          patient_dict[id].decision = curr_opt_hospital
    #################################################################
    ################# Step 2: 사망 여부 확인 업데이트 #################
    # 사망 여부 확인
    if tau - patient_dict[id].created_time > patient_dict[id].destiny:
      print("Time:",tau)
      print("환자 {}가 사망했습니다.".format(id))
      death_list.append(id)
      # 사망자 수 업데이트
      death_toll += 1
      continue

    #################################################################
    ############# Step 3: 병원 도착 여부 확인 업데이트 #############

    # 모든 환자가 각자 향하는 병원에 도착했는지 확인
    patient_lon, patient_lat = patient_dict[id].location
    #print("환자 {}의 현재 위치: {}".format(id, patient_dict[id].location))
    hospital_lon, hospital_lat = patient_dict[id].decision.location
    # 평면좌표계로 변환했으니, 0.1km = 100m 이내 도착시 도착으로 간주
    distance = np.sqrt((patient_lat - hospital_lat)**2 + (patient_lon - hospital_lon)**2)
    if distance < 0.01:
      # 환자의 treatment_time을 결정
      patient_dict[id].treatment_time = patient_dict[id].decision.sample_treat_time()      
      # 환자가 도착했다면, 환자를 patient_dict에서 삭제
      # 그 instance를 병원의 queue에 넣고, 병원의 len_queue를 1 증가
      patient_dict[id].decision.queue.append(patient_dict[id])
      patient_dict[id].decision.len_queue += 1
      if patient_dict[id].decision.treat_start == None:
        patient_dict[id].decision.treat_start = tau
      print("Time:",tau)
      print("환자 {}가 병원 {}에 도착했습니다.".format(id, patient_dict[id].decision.id))
      print("환자 {}가 병원 {}의 {}번째 환자가 되었습니다.".format(id, patient_dict[id].decision.id, patient_dict[id].decision.len_queue))
      print("환자 {}의 치료 시간은 {}입니다.".format(id, patient_dict[id].treatment_time))
      arrival_list.append(id)

  # 사망자 삭제
  for id in death_list:
    del patient_dict[id]

  # 도착자 삭제
  for id in arrival_list:
    del patient_dict[id]


  #################################################################
  ################# Step 4: 각 병원의 queue 업데이트 #################
  for key in hospitals_dict.keys():

    death_hospital_list = []
    treatment_hospital_list = []

    for i, patient in enumerate(hospitals_dict[key].queue[1:]):
      # 각 병원의 대기열 queue에 있는 환자들의 사망 여부 확인
      if tau - patient.created_time > patient.destiny:
        print("Time:",tau)
        print("환자 {}가 대기중인 병원 {}에서 사망했습니다.".format(patient.id, key))
        death_hospital_list.append(patient)
        # 사망자 수 업데이트
        death_toll += 1
        # 병원의 len_queue를 1 감소
        hospitals_dict[key].len_queue -= 1
        continue
    # 각 병원의 대기열 queue에 있는 환자들의 치료 완료 여부 확인
    if hospitals_dict[key].len_queue > 0:
      if tau - hospitals_dict[key].treat_start > hospitals_dict[key].queue[0].treatment_time:
        print("Time:",tau)
        print("환자 {}가 병원 {}에서 치료를 완료했습니다.".format(hospitals_dict[key].queue[0].id, key))
        # treatment_toll 업데이트
        treatment_toll += 1
        # etaw_toll 업데이트
        etaw_toll += tau - hospitals_dict[key].queue[0].created_time
        treatment_hospital_list.append(hospitals_dict[key].queue[0])
        # 병원의 len_queue를 1 감소
        hospitals_dict[key].len_queue -= 1

        if hospitals_dict[key].len_queue > 0:
          hospitals_dict[key].treat_start = tau
        else:
          hospitals_dict[key].treat_start = None

    # 사망자 삭제
    for patient in death_hospital_list:
      hospitals_dict[key].queue.remove(patient)

    # 치료 완료자 삭제
    for patient in treatment_hospital_list:
      hospitals_dict[key].queue.remove(patient)


def naive_optimizer(patient_id):
  """
  Just return the hospital that is closest to the patient
  Input: patient_id
  Output: hospital_id (closest)
  """
  global patient_dict, hospitals_dict, tau
  
  patient = patient_dict[patient_id]

  min_distance = sys.maxsize
  min_hospital = None

  for hospital_id in hospitals_dict.keys():
    # Calculate the distance using l2 norm
    distance = np.sqrt((patient.location[0] - hospitals_dict[hospital_id].location[0])**2 + (patient.location[1] - hospitals_dict[hospital_id].location[1])**2)
    if distance < min_distance:
      min_distance = distance
      min_hospital = hospitals_dict[hospital_id]

  # Return min_hospital
  return min_hospital


def optimizer(patient_id):
  """
  Return the hospital that minimizes the ETAW for each patient
  Input: patient_id
  Output: hospital_id (minimize ETAW)
  """
  global patient_dict, hospitals_dict, tau
  
  patient = patient_dict[patient_id]

  min_etaw = sys.maxsize
  min_hospital = None

  for hospital_id in hospitals_dict.keys():
    eta, etaw = compute_etaw(patient, hospitals_dict[hospital_id], tau)
    if etaw < min_etaw:
      min_etaw = etaw
      min_hospital = hospitals_dict[hospital_id]

  # Return min_hospital
  return min_hospital, min_etaw

# %%
with open('./config.json') as f:
    config = json.load(f)
    
model_type = input("Enter the model type: (opt or naive) ")

min_lat = config['min_lat']
max_lat = config['max_lat']
min_lon = config['min_lon']
max_lon = config['max_lon']

districts = config['districts'] # dict; {0: [(lon, lat), radius], ...}
# Transform the key of districts from str to int
districts = {int(key): districts[key] for key in districts.keys()}
weights = config['weights'] # list; population percentages
hospitals = config['hospitals'] # dict; {0: (lon, lat), ...}
# Transform the key of hospitals from str to int
hospitals = {int(key): hospitals[key] for key in hospitals.keys()}
mean_treat_times = config['mean_treat_times'] # list; average treatment time in each hospital
    
GRID = {'min_lat': min_lat, 'max_lat': max_lat, 'min_lon': min_lon, 'max_lon': max_lon}
patient_dict = {}  # dict; To store Patient instances
acc_patient_num = 0 # int; accumulated patient number

tau = 0 # Simulation global time step 
end_time = 24*3600

# Initialize the time points when patients occur on the map
patient_generate_mean = 1200

patient_generate_points = []
patient_destiny_list = []
patient_district_list = []
patient_location_list = []
time_point = 0

alpha_skewed = 8 # Standard Alpha
beta_skewed = 3 # Standard Beta 
a_skewed = 0 # Min 생존 시간
b_skewed = 3600 # Max 생존 시간

while time_point < end_time:
    sample = np.random.exponential(300, 1).astype(int)[0]
    time_point += sample
    d_id = np.random.choice(len(weights), p=weights)
    mean = districts[d_id][0]
    cov = [[districts[d_id][1]**2, 0], [0, districts[d_id][1]**2]]

    lon, lat = np.random.multivariate_normal(mean, cov)
    lat = max(min(lat, GRID['max_lat']), GRID['min_lat'])
    lon = max(min(lon, GRID['max_lon']), GRID['min_lon'])
    location = (lon, lat)
    destiny_temp = np.random.beta(alpha_skewed, beta_skewed, 1)
    destiny = a_skewed + (b_skewed - a_skewed) * destiny_temp
    
    if time_point < end_time:
        patient_generate_points.append(time_point)
        patient_destiny_list.append(destiny)
        patient_district_list.append(d_id)
        patient_location_list.append(location)
        

treatment_toll = 0
death_toll = 0
etaw_toll = 0
patient_toll = len(patient_generate_points)

hospitals_dict = {}
for id in range(len(hospitals)):
    hospitals_dict[id] = Hospital(id, hospitals[id], mean_treat_times[id])
    
metrics_df = pd.DataFrame(columns=['treatment_toll', 'death_toll', 'etaw_toll', 'patient_toll'])


def draw_cur_map():
    global tau, patient_dict, hospitals, min_lat, max_lat, min_lon, max_lon

    # Plot the current map
    plt.figure(figsize=(10, 10))
    m = Basemap(projection='merc', llcrnrlat=min_lat, urcrnrlat=max_lat, llcrnrlon=min_lon, urcrnrlon=max_lon, resolution='i')
    m.drawcoastlines()
    m.drawcountries()
    m.drawmapboundary(fill_color='white')
    m.fillcontinents(color='white', lake_color='white')
    m.drawparallels(np.arange(min_lat, max_lat, 0.1), labels=[1, 0, 0, 0])
    m.drawmeridians(np.arange(min_lon, max_lon, 0.1), labels=[0, 0, 0, 1])
    # Plot the hospitals
    for id in range(len(hospitals)):
        x, y = m(hospitals[id][0], hospitals[id][1])
        m.plot(x, y, 'bo', markersize=5)
    # Plot the patients
    for id in patient_dict.keys():
        x, y = m(patient_dict[id].location[0], patient_dict[id].location[1])
        m.plot(x, y, 'ro', markersize=5)
    plt.title("Time: {}".format(tau))
    plt.savefig('./images/{}.png'.format(tau))    


for tau in tqdm(range(0, end_time)):  # start_time should be defined, or use 0 if it starts from the beginning
    if tau in patient_generate_points:
        print("Time: {}".format(tau))
        create_patient(model_type, patient_location_list[0], patient_district_list[0], patient_destiny_list[0])  # Create patient
        patient_location_list.pop(0)
        patient_district_list.pop(0)
        patient_destiny_list.pop(0)
    updater(model_type)  # Update patient's location + alpha
    
    # Add the current metrics to the metrics_df
    metrics_df.loc[tau] = [treatment_toll, death_toll, etaw_toll, patient_toll]


# Save the metrics_df
if model_type == 'opt':
    metrics_df.to_csv('./metrics_df_opt.csv')
elif model_type == 'naive':
    metrics_df.to_csv('./metrics_df_naive.csv')
# Out:
#   0%|          | 0/36000 [00:00<?, ?it/s]
# Time: 7
# 환자 0가 생성되었습니다. 위치: (11205.987622295956, 3560.880915370534), 생성 시간: 7, 사망 시간: [2662.98279559]
# 환자 0의 eta: 1213.1227906769388, etaw: 1213.1227906769388
# Time: 100
# 환자 1가 생성되었습니다. 위치: (11218.632405853385, 3556.411401848312), 생성 시간: 100, 사망 시간: [2229.56474541]
# 환자 1의 eta: 895.8606279715177, etaw: 895.8606279715177
# Time: 304
# 환자 2가 생성되었습니다. 위치: (11210.89681027845, 3558.45383156766), 생성 시간: 304, 사망 시간: [2931.14361593]
# 환자 2의 eta: 620.1370499892918, etaw: 620.1370499892918
# Time: 576
# 환자 3가 생성되었습니다. 위치: (11215.11547625494, 3554.535286045994), 생성 시간: 576, 사망 시간: [3349.35887998]
# 환자 3의 eta: 680.5070145655511, etaw: 680.5070145655511
# Time: 773
# 환자 4가 생성되었습니다. 위치: (11217.59999285567, 3558.1350336893597), 생성 시간: 773, 사망 시간: [2183.00199385]
# 환자 4의 eta: 406.4078624957444, etaw: 406.4078624957444
# Time: 920
# 환자 2가 병원 30에 도착했습니다.
# 환자 2가 병원 30의 1번째 환자가 되었습니다.
# 환자 2의 치료 시간은 [5154.22789893]입니다.
# Time: 980
# 환자 5가 생성되었습니다. 위치: (11216.280593813099, 3563.4229348998856), 생성 시간: 980, 사망 시간: [3123.84573026]
# 환자 5의 eta: 710.1167365164379, etaw: 710.1167365164379
# Time: 992
# 환자 1가 병원 12에 도착했습니다.
# 환자 1가 병원 12의 1번째 환자가 되었습니다.
# 환자 1의 치료 시간은 [4008.84392139]입니다.
# Time: 1175
# 환자 4가 병원 11에 도착했습니다.
# 환자 4가 병원 11의 1번째 환자가 되었습니다.
# 환자 4의 치료 시간은 [4008.84392139]입니다.
# Time: 1216
# 환자 0가 병원 26에 도착했습니다.
# 환자 0가 병원 26의 1번째 환자가 되었습니다.
# 환자 0의 치료 시간은 [5154.22789893]입니다.
# Time: 1252
# 환자 3가 병원 24에 도착했습니다.
# 환자 3가 병원 24의 1번째 환자가 되었습니다.
# 환자 3의 치료 시간은 [5154.22789893]입니다.
# Time: 1686
# 환자 5가 병원 13에 도착했습니다.
# 환자 5가 병원 13의 1번째 환자가 되었습니다.
# 환자 5의 치료 시간은 [4008.84392139]입니다.
# Time: 1902
# 환자 6가 생성되었습니다. 위치: (11210.764498048064, 3563.3562083014103), 생성 시간: 1902, 사망 시간: [2107.2091802]
# 환자 6의 eta: 580.6864421525988, etaw: 580.6864421525988
# Time: 1922
# 환자 7가 생성되었습니다. 위치: (11231.67182742328, 3571.0152449820366), 생성 시간: 1922, 사망 시간: [2902.80019925]
# 환자 7의 eta: 1081.5934057132704, etaw: 1081.5934057132704
# Time: 1936
# 환자 8가 생성되었습니다. 위치: (11228.746510379633, 3562.6213197827838), 생성 시간: 1936, 사망 시간: [2752.4335205]
# 환자 8의 eta: 721.0696457159466, etaw: 721.0696457159466
# Time: 2336
# 환자 9가 생성되었습니다. 위치: (11226.99769251532, 3569.6522894627537), 생성 시간: 2336, 사망 시간: [3445.25575339]
# 환자 9의 eta: 679.7187578401614, etaw: 679.7187578401614
# Time: 2479
# 환자 6가 병원 3에 도착했습니다.
# 환자 6가 병원 3의 1번째 환자가 되었습니다.
# 환자 6의 치료 시간은 [2863.45994385]입니다.
# Time: 2576
# 환자 10가 생성되었습니다. 위치: (11227.443967917005, 3568.0065318535953), 생성 시간: 2576, 사망 시간: [2021.0379583]
# 환자 10의 eta: 593.6769293263992, etaw: 593.6769293263992
# Time: 2653
# 환자 8가 병원 10에 도착했습니다.
# 환자 8가 병원 10의 1번째 환자가 되었습니다.
# 환자 8의 치료 시간은 [4008.84392139]입니다.
# Time: 2900
# 환자 11가 생성되었습니다. 위치: (11207.80972534755, 3564.927561378843), 생성 시간: 2900, 사망 시간: [2597.93641948]
# 환자 11의 eta: 834.6399970364831, etaw: 18834.639997036484
# Time: 2999
# 환자 7가 병원 20에 도착했습니다.
# 환자 7가 병원 20의 1번째 환자가 되었습니다.
# 환자 7의 치료 시간은 [5154.22789893]입니다.
# Time: 3012
# 환자 9가 병원 20에 도착했습니다.
# 환자 9가 병원 20의 2번째 환자가 되었습니다.
# 환자 9의 치료 시간은 [5154.22789893]입니다.
# Time: 3166
# 환자 10가 병원 18에 도착했습니다.
# 환자 10가 병원 18의 1번째 환자가 되었습니다.
# 환자 10의 치료 시간은 [4008.84392139]입니다.
# Time: 3651
# 환자 12가 생성되었습니다. 위치: (11218.020263462598, 3552.8749156136173), 생성 시간: 3651, 사망 시간: [2273.95565301]
# 환자 12의 eta: 1833.682348005054, etaw: 19833.682348005055
# Time: 3731
# 환자 11가 병원 26에 도착했습니다.
# 환자 11가 병원 26의 2번째 환자가 되었습니다.
# 환자 11의 치료 시간은 [5154.22789893]입니다.
# Time: 4176
# 환자 13가 생성되었습니다. 위치: (11224.252012583693, 3551.375326796228), 생성 시간: 4176, 사망 시간: [3303.96152184]
# 환자 13의 eta: 2053.4678372751177, etaw: 2053.4678372751177
# Time: 4237
# 환자 14가 생성되었습니다. 위치: (11218.389893186037, 3575.8625186872796), 생성 시간: 4237, 사망 시간: [2744.17516834]
# 환자 14의 eta: 1653.4116890983576, etaw: 1653.4116890983576
# Time: 4476
# 환자 15가 생성되었습니다. 위치: (11212.729289039688, 3557.3023462153656), 생성 시간: 4476, 사망 시간: [3113.29750032]
# 환자 15의 eta: 229.40959021875904, etaw: 229.40959021875904
# Time: 4485
# 환자 16가 생성되었습니다. 위치: (11214.210029570375, 3556.264576543981), 생성 시간: 4485, 사망 시간: [2761.76690593]
# 환자 16의 eta: 60.768546783131505, etaw: 18060.768546783132
# Time: 4505
# 환자 17가 생성되었습니다. 위치: (11230.031598476138, 3556.1804716994743), 생성 시간: 4505, 사망 시간: [2834.54333549]
# 환자 17의 eta: 844.9586206347254, etaw: 844.9586206347254
# Time: 4542
# 환자 16가 병원 24에 도착했습니다.
# 환자 16가 병원 24의 2번째 환자가 되었습니다.
# 환자 16의 치료 시간은 [5154.22789893]입니다.
# Time: 4607
# 환자 18가 생성되었습니다. 위치: (11222.661919835391, 3558.3831834349226), 생성 시간: 4607, 사망 시간: [3137.65807106]
# 환자 18의 eta: 714.1204485719551, etaw: 714.1204485719551
# Time: 4701
# 환자 15가 병원 19에 도착했습니다.
# 환자 15가 병원 19의 1번째 환자가 되었습니다.
# 환자 15의 치료 시간은 [4008.84392139]입니다.
# Time: 4830
# 환자 19가 생성되었습니다. 위치: (11223.595519236404, 3555.4149386171575), 생성 시간: 4830, 사망 시간: [2612.28092343]
# 환자 19의 eta: 632.0210120745234, etaw: 632.0210120745234
# Time: 5001
# 환자 1가 병원 12에서 치료를 완료했습니다.
# Time: 5184
# 환자 4가 병원 11에서 치료를 완료했습니다.
# Time: 5317
# 환자 18가 병원 9에 도착했습니다.
# 환자 18가 병원 9의 1번째 환자가 되었습니다.
# 환자 18의 치료 시간은 [2863.45994385]입니다.
# Time: 5343
# 환자 6가 병원 3에서 치료를 완료했습니다.
# Time: 5346
# 환자 17가 병원 8에 도착했습니다.
# 환자 17가 병원 8의 1번째 환자가 되었습니다.
# 환자 17의 치료 시간은 [2863.45994385]입니다.
# Time: 5458
# 환자 19가 병원 9에 도착했습니다.
# 환자 19가 병원 9의 2번째 환자가 되었습니다.
# 환자 19의 치료 시간은 [2863.45994385]입니다.
# Time: 5481
# 환자 12가 병원 24에 도착했습니다.
# 환자 12가 병원 24의 3번째 환자가 되었습니다.
# 환자 12의 치료 시간은 [5154.22789893]입니다.
# Time: 5498
# 환자 11가 대기중인 병원 26에서 사망했습니다.
# Time: 5695
# 환자 5가 병원 13에서 치료를 완료했습니다.
# Time: 5772
# 환자 20가 생성되었습니다. 위치: (11214.213157010025, 3552.8009077948823), 생성 시간: 5772, 사망 시간: [2125.11350098]
# 환자 20의 eta: 1200.0642954904997, etaw: 43788.52156361039
# Time: 5782
# 환자 9가 대기중인 병원 20에서 사망했습니다.
# Time: 5886
# 환자 14가 병원 25에 도착했습니다.
# 환자 14가 병원 25의 1번째 환자가 되었습니다.
# 환자 14의 치료 시간은 [5154.22789893]입니다.
# Time: 5925
# 환자 12가 대기중인 병원 24에서 사망했습니다.
# Time: 6075
# 환자 2가 병원 30에서 치료를 완료했습니다.
# Time: 6149
# 환자 21가 생성되었습니다. 위치: (11225.28536898669, 3557.224377939417), 생성 시간: 6149, 사망 시간: [2727.35343265]
# 환자 21의 eta: 409.85924255440364, etaw: 17480.92705441988
# Time: 6225
# 환자 13가 병원 9에 도착했습니다.
# 환자 13가 병원 9의 3번째 환자가 되었습니다.
# 환자 13의 치료 시간은 [2863.45994385]입니다.
# Time: 6371
# 환자 0가 병원 26에서 치료를 완료했습니다.
# Time: 6402
# 환자 22가 생성되었습니다. 위치: (11213.836064568612, 3575.1236390816407), 생성 시간: 6402, 사망 시간: [2182.14472287]
# 환자 22의 eta: 968.6172222561679, etaw: 968.6172222561679
# Time: 6407
# 환자 3가 병원 24에서 치료를 완료했습니다.
# Time: 6555
# 환자 21가 병원 9에 도착했습니다.
# 환자 21가 병원 9의 4번째 환자가 되었습니다.
# 환자 21의 치료 시간은 [2863.45994385]입니다.
# Time: 6650
# 환자 23가 생성되었습니다. 위치: (11221.603356862428, 3562.7301040197203), 생성 시간: 6650, 사망 시간: [2504.57515971]
# 환자 23의 eta: 572.5732196260806, etaw: 572.5732196260806
# Time: 6662
# 환자 8가 병원 10에서 치료를 완료했습니다.
# Time: 6968
# 환자 20가 병원 24에 도착했습니다.
# 환자 20가 병원 24의 2번째 환자가 되었습니다.
# 환자 20의 치료 시간은 [5154.22789893]입니다.
# Time: 7175
# 환자 10가 병원 18에서 치료를 완료했습니다.
# Time: 7218
# 환자 23가 병원 23에 도착했습니다.
# 환자 23가 병원 23의 1번째 환자가 되었습니다.
# 환자 23의 치료 시간은 [5154.22789893]입니다.
# Time: 7256
# 환자 24가 생성되었습니다. 위치: (11210.319081787122, 3555.2790167378703), 생성 시간: 7256, 사망 시간: [2609.39894498]
# 환자 24의 eta: 639.7074918735794, etaw: 639.7074918735794
# Time: 7367
# 환자 22가 병원 14에 도착했습니다.
# 환자 22가 병원 14의 1번째 환자가 되었습니다.
# 환자 22의 치료 시간은 [4008.84392139]입니다.
# Time: 7443
# 환자 19가 대기중인 병원 9에서 사망했습니다.
# Time: 7480
# 환자 13가 대기중인 병원 9에서 사망했습니다.
# Time: 7743
# 환자 25가 생성되었습니다. 위치: (11223.691611755059, 3556.4442705074534), 생성 시간: 7743, 사망 시간: [2871.64597646]
# 환자 25의 eta: 283.0652987253362, etaw: 17354.133110590814
# Time: 7892
# 환자 24가 병원 1에 도착했습니다.
# 환자 24가 병원 1의 1번째 환자가 되었습니다.
# 환자 24의 치료 시간은 [2863.45994385]입니다.
# Time: 7898
# 환자 20가 대기중인 병원 24에서 사망했습니다.
# Time: 8022
# 환자 25가 병원 9에 도착했습니다.
# 환자 25가 병원 9의 3번째 환자가 되었습니다.
# 환자 25의 치료 시간은 [2863.45994385]입니다.
# Time: 8154
# 환자 7가 병원 20에서 치료를 완료했습니다.
# Time: 8181
# 환자 18가 병원 9에서 치료를 완료했습니다.
# Time: 8183
# 환자 26가 생성되었습니다. 위치: (11212.05435352098, 3550.4102219175406), 생성 시간: 8183, 사망 시간: [2870.5575487]
# 환자 26의 eta: 2188.32138521924, etaw: 20188.32138521924
# Time: 8210
# 환자 17가 병원 8에서 치료를 완료했습니다.
# Time: 8710
# 환자 15가 병원 19에서 치료를 완료했습니다.
# Time: 8762
# 환자 27가 생성되었습니다. 위치: (11226.833249294563, 3572.993794536706), 생성 시간: 8762, 사망 시간: [2236.58837251]
# 환자 27의 eta: 210.467954354038, etaw: 210.467954354038
# Time: 8846
# 환자 28가 생성되었습니다. 위치: (11207.168266447394, 3560.5274102653775), 생성 시간: 8846, 사망 시간: [2097.73573171]
# 환자 28의 eta: 1141.458527030227, etaw: 1141.458527030227
# Time: 8951
# 환자 29가 생성되었습니다. 위치: (11213.763941297717, 3560.057776430562), 생성 시간: 8951, 사망 시간: [2915.30640106]
# 환자 29의 eta: 262.0304921572825, etaw: 262.0304921572825
# Time: 8968
# 환자 27가 병원 17에 도착했습니다.
# 환자 27가 병원 17의 1번째 환자가 되었습니다.
# 환자 27의 치료 시간은 [4008.84392139]입니다.
# Time: 9209
# 환자 29가 병원 15에 도착했습니다.
# 환자 29가 병원 15의 1번째 환자가 되었습니다.
# 환자 29의 치료 시간은 [4008.84392139]입니다.
# Time: 9325
# 환자 30가 생성되었습니다. 위치: (11211.1123656598, 3569.1271418967413), 생성 시간: 9325, 사망 시간: [2159.4745226]
# 환자 30의 eta: 1402.9848338702307, etaw: 15402.98483387023
# Time: 9862
# 환자 31가 생성되었습니다. 위치: (11211.475959501813, 3559.649314017244), 생성 시간: 9862, 사망 시간: [2663.24046517]
# 환자 31의 eta: 642.3767289056098, etaw: 642.3767289056098
# Time: 9983
# 환자 28가 병원 3에 도착했습니다.
# 환자 28가 병원 3의 1번째 환자가 되었습니다.
# 환자 28의 치료 시간은 [2863.45994385]입니다.
# Time: 10169
# 환자 32가 생성되었습니다. 위치: (11226.808802015445, 3564.739329011807), 생성 시간: 10169, 사망 시간: [2143.62237849]
# 환자 32의 eta: 850.3907663704359, etaw: 850.3907663704359
# Time: 10259
# 환자 33가 생성되었습니다. 위치: (11224.092148136926, 3574.863677534378), 생성 시간: 10259, 사망 시간: [2570.48934269]
# 환자 33의 eta: 585.2968396008205, etaw: 585.2968396008205
# Time: 10367
# 환자 26가 병원 24에 도착했습니다.
# 환자 26가 병원 24의 2번째 환자가 되었습니다.
# 환자 26의 치료 시간은 [5154.22789893]입니다.
# Time: 10398
# 환자 34가 생성되었습니다. 위치: (11228.2894567171, 3557.691054626066), 생성 시간: 10398, 사망 시간: [1804.1447029]
# 환자 34의 eta: 441.6819226134058, etaw: 441.6819226134058
# Time: 10500
# 환자 31가 병원 22에 도착했습니다.
# 환자 31가 병원 22의 1번째 환자가 되었습니다.
# 환자 31의 치료 시간은 [5154.22789893]입니다.
# Time: 10615
# 환자 25가 대기중인 병원 9에서 사망했습니다.
# Time: 10724
# 환자 30가 병원 14에 도착했습니다.
# 환자 30가 병원 14의 2번째 환자가 되었습니다.
# 환자 30의 치료 시간은 [4008.84392139]입니다.
# Time: 10756
# 환자 24가 병원 1에서 치료를 완료했습니다.
# Time: 10836
# 환자 34가 병원 8에 도착했습니다.
# 환자 34가 병원 8의 1번째 환자가 되었습니다.
# 환자 34의 치료 시간은 [2863.45994385]입니다.
# Time: 10840
# 환자 33가 병원 27에 도착했습니다.
# 환자 33가 병원 27의 1번째 환자가 되었습니다.
# 환자 33의 치료 시간은 [5154.22789893]입니다.
# Time: 11015
# 환자 32가 병원 6에 도착했습니다.
# 환자 32가 병원 6의 1번째 환자가 되었습니다.
# 환자 32의 치료 시간은 [2863.45994385]입니다.
# Time: 11041
# 환자 14가 병원 25에서 치료를 완료했습니다.
# Time: 11045
# 환자 21가 병원 9에서 치료를 완료했습니다.
# Time: 11054
# 환자 26가 대기중인 병원 24에서 사망했습니다.
# Time: 11309
# 환자 35가 생성되었습니다. 위치: (11219.883195964596, 3567.886076343993), 생성 시간: 11309, 사망 시간: [1588.38737457]
# 환자 35의 eta: 422.82728862664334, etaw: 422.82728862664334
# Time: 11376
# 환자 22가 병원 14에서 치료를 완료했습니다.
# Time: 11397
# 환자 36가 생성되었습니다. 위치: (11202.714431696237, 3561.39962874582), 생성 시간: 11397, 사망 시간: [2457.55685826]
# 환자 36의 eta: 1454.4772544710333, etaw: 1454.4772544710333
# Time: 11562
# 환자 16가 병원 24에서 치료를 완료했습니다.
# Time: 11584
# 환자 37가 생성되었습니다. 위치: (11221.607989877066, 3573.55021479542), 생성 시간: 11584, 사망 시간: [2892.07703849]
# 환자 37의 eta: 416.53416955107605, etaw: 416.53416955107605
# Time: 11728
# 환자 35가 병원 2에 도착했습니다.
# 환자 35가 병원 2의 1번째 환자가 되었습니다.
# 환자 35의 치료 시간은 [2863.45994385]입니다.
# Time: 11894
# 환자 38가 생성되었습니다. 위치: (11209.420540109704, 3559.696504264143), 생성 시간: 11894, 사망 시간: [2698.81202561]
# 환자 38의 eta: 831.5717177063618, etaw: 10831.571717706362
# Time: 11904
# 환자 39가 생성되었습니다. 위치: (11215.22172955286, 3559.325625253582), 생성 시간: 11904, 사망 시간: [2811.06100055]
# 환자 39의 eta: 339.70409902381203, etaw: 14339.704099023813
# Time: 11923
# 환자 40가 생성되었습니다. 위치: (11205.742847933887, 3564.322874957846), 생성 시간: 11923, 사망 시간: [2576.53849711]
# 환자 40의 eta: 61.90645884578405, etaw: 61.90645884578405
# Time: 11953
# 환자 41가 생성되었습니다. 위치: (11212.986252186138, 3559.570028248243), 생성 시간: 11953, 사망 시간: [3049.24436083]
# 환자 41의 eta: 151.07398285251014, etaw: 18151.07398285251
# Time: 11981
# 환자 40가 병원 26에 도착했습니다.
# 환자 40가 병원 26의 1번째 환자가 되었습니다.
# 환자 40의 치료 시간은 [5154.22789893]입니다.
# Time: 11996
# 환자 37가 병원 25에 도착했습니다.
# 환자 37가 병원 25의 1번째 환자가 되었습니다.
# 환자 37의 치료 시간은 [5154.22789893]입니다.
# Time: 12100
# 환자 41가 병원 22에 도착했습니다.
# 환자 41가 병원 22의 2번째 환자가 되었습니다.
# 환자 41의 치료 시간은 [5154.22789893]입니다.
# Time: 12208
# 환자 42가 생성되었습니다. 위치: (11202.781628047866, 3560.6608580002744), 생성 시간: 12208, 사망 시간: [3001.85974905]
# 환자 42의 eta: 1636.528982891976, etaw: 19636.528982891978
# Time: 12240
# 환자 39가 병원 15에 도착했습니다.
# 환자 39가 병원 15의 2번째 환자가 되었습니다.
# 환자 39의 치료 시간은 [4008.84392139]입니다.
# Time: 12373
# 환자 23가 병원 23에서 치료를 완료했습니다.
# Time: 12440
# 환자 43가 생성되었습니다. 위치: (11229.540562435373, 3560.201659272699), 생성 시간: 12440, 사망 시간: [2932.10245192]
# 환자 43의 eta: 225.61599592872113, etaw: 225.61599592872113
# Time: 12450
# 환자 44가 생성되었습니다. 위치: (11213.205451762418, 3559.5022025681333), 생성 시간: 12450, 사망 시간: [1965.63141749]
# 환자 44의 eta: 104.27504475298903, etaw: 30832.197106110845
# Time: 12550
# 환자 44가 병원 22에 도착했습니다.
# 환자 44가 병원 22의 3번째 환자가 되었습니다.
# 환자 44의 치료 시간은 [5154.22789893]입니다.
# Time: 12596
# 환자 45가 생성되었습니다. 위치: (11211.710373646025, 3561.148368000501), 생성 시간: 12596, 사망 시간: [3433.80127046]
# 환자 45의 eta: 672.8960540465922, etaw: 10672.896054046592
# Time: 12662
# 환자 43가 병원 10에 도착했습니다.
# 환자 43가 병원 10의 1번째 환자가 되었습니다.
# 환자 43의 치료 시간은 [4008.84392139]입니다.
# Time: 12721
# 환자 38가 병원 3에 도착했습니다.
# 환자 38가 병원 3의 2번째 환자가 되었습니다.
# 환자 38의 치료 시간은 [2863.45994385]입니다.
# Time: 12847
# 환자 36가 병원 26에 도착했습니다.
# 환자 36가 병원 26의 2번째 환자가 되었습니다.
# 환자 36의 치료 시간은 [5154.22789893]입니다.
# Time: 12847
# 환자 28가 병원 3에서 치료를 완료했습니다.
# Time: 12977
# 환자 27가 병원 17에서 치료를 완료했습니다.
# Time: 12998
# 환자 46가 생성되었습니다. 위치: (11213.912561835215, 3562.9796014692506), 생성 시간: 12998, 사망 시간: [2681.45777404]
# 환자 46의 eta: 724.4760350975465, etaw: 724.4760350975465
# Time: 13218
# 환자 29가 병원 15에서 치료를 완료했습니다.
# Time: 13265
# 환자 45가 병원 3에 도착했습니다.
# 환자 45가 병원 3의 2번째 환자가 되었습니다.
# 환자 45의 치료 시간은 [2863.45994385]입니다.
# Time: 13700
# 환자 34가 병원 8에서 치료를 완료했습니다.
# Time: 13718
# 환자 46가 병원 13에 도착했습니다.
# 환자 46가 병원 13의 1번째 환자가 되었습니다.
# 환자 46의 치료 시간은 [4008.84392139]입니다.
# Time: 13840
# 환자 42가 병원 26에 도착했습니다.
# 환자 42가 병원 26의 3번째 환자가 되었습니다.
# 환자 42의 치료 시간은 [5154.22789893]입니다.
# Time: 13855
# 환자 36가 대기중인 병원 26에서 사망했습니다.
# Time: 13879
# 환자 32가 병원 6에서 치료를 완료했습니다.
# Time: 13974
# 환자 47가 생성되었습니다. 위치: (11220.620878174417, 3565.753281937784), 생성 시간: 13974, 사망 시간: [2703.68800908]
# 환자 47의 eta: 417.43861489010027, etaw: 10417.4386148901
# Time: 14223
# 환자 48가 생성되었습니다. 위치: (11215.714911339703, 3565.2234865557493), 생성 시간: 14223, 사망 시간: [2971.49590762]
# 환자 48의 eta: 356.20053266086234, etaw: 14356.200532660863
# Time: 14387
# 환자 47가 병원 2에 도착했습니다.
# 환자 47가 병원 2의 2번째 환자가 되었습니다.
# 환자 47의 치료 시간은 [2863.45994385]입니다.
# Time: 14393
# 환자 49가 생성되었습니다. 위치: (11219.933375732371, 3551.2794551773613), 생성 시간: 14393, 사망 시간: [3241.91041592]
# 환자 49의 eta: 2454.6790107532324, etaw: 2454.6790107532324
# Time: 14416
# 환자 44가 대기중인 병원 22에서 사망했습니다.
# Time: 14575
# 환자 48가 병원 13에 도착했습니다.
# 환자 48가 병원 13의 2번째 환자가 되었습니다.
# 환자 48의 치료 시간은 [4008.84392139]입니다.
# Time: 14592
# 환자 35가 병원 2에서 치료를 완료했습니다.
# Time: 14972
# 환자 50가 생성되었습니다. 위치: (11228.696886180125, 3571.966633416915), 생성 시간: 14972, 사망 시간: [3251.19549451]
# 환자 50의 eta: 563.5237456132704, etaw: 563.5237456132704
# Time: 15003
# 환자 41가 대기중인 병원 22에서 사망했습니다.
# Time: 15210
# 환자 42가 대기중인 병원 26에서 사망했습니다.
# Time: 15385
# 환자 30가 병원 14에서 치료를 완료했습니다.
# Time: 15531
# 환자 50가 병원 20에 도착했습니다.
# 환자 50가 병원 20의 1번째 환자가 되었습니다.
# 환자 50의 치료 시간은 [5154.22789893]입니다.
# Time: 15655
# 환자 31가 병원 22에서 치료를 완료했습니다.
# Time: 15711
# 환자 38가 병원 3에서 치료를 완료했습니다.
# Time: 15788
# 환자 51가 생성되었습니다. 위치: (11225.158861686172, 3560.9612731545562), 생성 시간: 15788, 사망 시간: [1245.77539008]
# 환자 51의 eta: 694.4845587478732, etaw: 694.4845587478732
# Time: 15995
# 환자 33가 병원 27에서 치료를 완료했습니다.
# Time: 16021
# 환자 52가 생성되었습니다. 위치: (11216.065394367313, 3569.696571104046), 생성 시간: 16021, 사망 시간: [3198.08563796]
# 환자 52의 eta: 1576.6316480313076, etaw: 1576.6316480313076
# Time: 16347
# 환자 53가 생성되었습니다. 위치: (11226.697866324646, 3558.977083950675), 생성 시간: 16347, 사망 시간: [3155.3814724]
# 환자 53의 eta: 930.9656135289147, etaw: 930.9656135289147
# Time: 16478
# 환자 51가 병원 6에 도착했습니다.
# 환자 51가 병원 6의 1번째 환자가 되었습니다.
# 환자 51의 치료 시간은 [2863.45994385]입니다.
# Time: 16671
# 환자 43가 병원 10에서 치료를 완료했습니다.
# Time: 16844
# 환자 49가 병원 12에 도착했습니다.
# 환자 49가 병원 12의 1번째 환자가 되었습니다.
# 환자 49의 치료 시간은 [4008.84392139]입니다.
# Time: 17136
# 환자 40가 병원 26에서 치료를 완료했습니다.
# Time: 17151
# 환자 37가 병원 25에서 치료를 완료했습니다.
# Time: 17195
# 환자 48가 대기중인 병원 13에서 사망했습니다.
# Time: 17227
# 환자 39가 병원 15에서 치료를 완료했습니다.
# Time: 17274
# 환자 53가 병원 8에 도착했습니다.
# 환자 53가 병원 8의 1번째 환자가 되었습니다.
# 환자 53의 치료 시간은 [2863.45994385]입니다.
# Time: 17456
# 환자 47가 병원 2에서 치료를 완료했습니다.
# Time: 17500
# 환자 54가 생성되었습니다. 위치: (11219.458529556512, 3576.264833074683), 생성 시간: 17500, 사망 시간: [2918.79290077]
# 환자 54의 eta: 1383.0876459996052, etaw: 1383.0876459996052
# Time: 17594
# 환자 52가 병원 5에 도착했습니다.
# 환자 52가 병원 5의 1번째 환자가 되었습니다.
# 환자 52의 치료 시간은 [2863.45994385]입니다.
# Time: 17727
# 환자 46가 병원 13에서 치료를 완료했습니다.
# Time: 18012
# 환자 55가 생성되었습니다. 위치: (11222.64289754636, 3577.8596970496556), 생성 시간: 18012, 사망 시간: [1839.81353517]
# 환자 55의 eta: 1355.38455448119, etaw: 1355.38455448119
# Time: 18091
# 환자 56가 생성되었습니다. 위치: (11230.294951640297, 3564.4198636407623), 생성 시간: 18091, 사망 시간: [2902.80382244]
# 환자 56의 eta: 1108.0192435463398, etaw: 1108.0192435463398
# Time: 18575
# 환자 45가 병원 3에서 치료를 완료했습니다.
# Time: 18662
# 환자 57가 생성되었습니다. 위치: (11218.953433830942, 3559.618499621797), 생성 시간: 18662, 사망 시간: [2811.44986916]
# 환자 57의 eta: 781.8858318615678, etaw: 14781.885831861568
# Time: 18879
# 환자 54가 병원 25에 도착했습니다.
# 환자 54가 병원 25의 1번째 환자가 되었습니다.
# 환자 54의 치료 시간은 [5154.22789893]입니다.
# Time: 19195
# 환자 56가 병원 21에 도착했습니다.
# 환자 56가 병원 21의 1번째 환자가 되었습니다.
# 환자 56의 치료 시간은 [5154.22789893]입니다.
# Time: 19342
# 환자 51가 병원 6에서 치료를 완료했습니다.
# Time: 19363
# 환자 55가 병원 25에 도착했습니다.
# 환자 55가 병원 25의 2번째 환자가 되었습니다.
# 환자 55의 치료 시간은 [5154.22789893]입니다.
# Time: 19440
# 환자 57가 병원 12에 도착했습니다.
# 환자 57가 병원 12의 2번째 환자가 되었습니다.
# 환자 57의 치료 시간은 [4008.84392139]입니다.
# Time: 19583
# 환자 58가 생성되었습니다. 위치: (11210.890540982635, 3569.003549133846), 생성 시간: 19583, 사망 시간: [2194.04561714]
# 환자 58의 eta: 1476.532968502286, etaw: 1476.532968502286
# Time: 19649
# 환자 59가 생성되었습니다. 위치: (11225.077369499226, 3574.42598656865), 생성 시간: 19649, 사망 시간: [2655.25036859]
# 환자 59의 eta: 203.87962910619166, etaw: 203.87962910619166
# Time: 19704
# 환자 60가 생성되었습니다. 위치: (11208.556426276726, 3552.80085417362), 생성 시간: 19704, 사망 시간: [2494.1678503]
# 환자 60의 eta: 1585.7483688698521, etaw: 1585.7483688698521
# Time: 19801
# 환자 61가 생성되었습니다. 위치: (11216.027911734662, 3559.628613775052), 생성 시간: 19801, 사망 시간: [2678.69397486]
# 환자 61의 eta: 404.93875437274403, etaw: 404.93875437274403
# Time: 19849
# 환자 59가 병원 27에 도착했습니다.
# 환자 59가 병원 27의 1번째 환자가 되었습니다.
# 환자 59의 치료 시간은 [5154.22789893]입니다.
# Time: 19852
# 환자 55가 대기중인 병원 25에서 사망했습니다.
# Time: 20138
# 환자 53가 병원 8에서 치료를 완료했습니다.
# Time: 20140
# 환자 62가 생성되었습니다. 위치: (11201.270383594494, 3562.3860696838588), 생성 시간: 20140, 사망 시간: [2848.55731249]
# 환자 62의 eta: 1693.6388949716222, etaw: 1693.6388949716222
# Time: 20202
# 환자 61가 병원 11에 도착했습니다.
# 환자 61가 병원 11의 1번째 환자가 되었습니다.
# 환자 61의 치료 시간은 [4008.84392139]입니다.
# Time: 20458
# 환자 52가 병원 5에서 치료를 완료했습니다.
# Time: 20550
# 환자 63가 생성되었습니다. 위치: (11212.076687191304, 3555.4146970058337), 생성 시간: 20550, 사망 시간: [2380.02137142]
# 환자 63의 eta: 617.3413434957569, etaw: 617.3413434957569
# Time: 20686
# 환자 50가 병원 20에서 치료를 완료했습니다.
# Time: 20853
# 환자 49가 병원 12에서 치료를 완료했습니다.
# Time: 21055
# 환자 58가 병원 14에 도착했습니다.
# 환자 58가 병원 14의 1번째 환자가 되었습니다.
# 환자 58의 치료 시간은 [4008.84392139]입니다.
# Time: 21163
# 환자 63가 병원 30에 도착했습니다.
# 환자 63가 병원 30의 1번째 환자가 되었습니다.
# 환자 63의 치료 시간은 [5154.22789893]입니다.
# Time: 21286
# 환자 60가 병원 1에 도착했습니다.
# 환자 60가 병원 1의 1번째 환자가 되었습니다.
# 환자 60의 치료 시간은 [2863.45994385]입니다.
# Time: 21830
# 환자 62가 병원 26에 도착했습니다.
# 환자 62가 병원 26의 1번째 환자가 되었습니다.
# 환자 62의 치료 시간은 [5154.22789893]입니다.
# Time: 21995
# 환자 64가 생성되었습니다. 위치: (11227.636960120966, 3567.6163374627695), 생성 시간: 21995, 사망 시간: [2254.10510087]
# 환자 64의 eta: 648.2993035497544, etaw: 648.2993035497544
# Time: 22038
# 환자 65가 생성되었습니다. 위치: (11214.568366153602, 3559.3184642852843), 생성 시간: 22038, 사망 시간: [3408.39373245]
# 환자 65의 eta: 212.96370749480081, etaw: 212.96370749480081
# Time: 22155
# 환자 66가 생성되었습니다. 위치: (11221.369501605064, 3560.7175965980805), 생성 시간: 22155, 사망 시간: [2592.2624396]
# 환자 66의 eta: 464.98090616813147, etaw: 464.98090616813147
# Time: 22247
# 환자 65가 병원 15에 도착했습니다.
# 환자 65가 병원 15의 1번째 환자가 되었습니다.
# 환자 65의 치료 시간은 [4008.84392139]입니다.
# Time: 22392
# 환자 67가 생성되었습니다. 위치: (11210.7819823329, 3568.987875416969), 생성 시간: 22392, 사망 시간: [2957.14318678]
# 환자 67의 eta: 1498.815433363654, etaw: 15498.815433363654
# Time: 22408
# 환자 68가 생성되었습니다. 위치: (11210.970721044076, 3562.5529086530114), 생성 시간: 22408, 사망 시간: [3202.66107537]
# 환자 68의 eta: 411.6553532844083, etaw: 411.6553532844083
# Time: 22512
# 환자 69가 생성되었습니다. 위치: (11207.569760214194, 3557.1668450771867), 생성 시간: 22512, 사망 시간: [1928.68667906]
# 환자 69의 eta: 834.6177104416126, etaw: 10834.617710441613
# Time: 22589
# 환자 70가 생성되었습니다. 위치: (11208.642436703636, 3560.1795010490405), 생성 시간: 22589, 사망 시간: [2463.33998079]
# 환자 70의 eta: 800.0012301448262, etaw: 800.0012301448262
# Time: 22616
# 환자 66가 병원 23에 도착했습니다.
# 환자 66가 병원 23의 1번째 환자가 되었습니다.
# 환자 66의 치료 시간은 [5154.22789893]입니다.
# Time: 22639
# 환자 64가 병원 18에 도착했습니다.
# 환자 64가 병원 18의 1번째 환자가 되었습니다.
# 환자 64의 치료 시간은 [4008.84392139]입니다.
# Time: 22779
# 환자 71가 생성되었습니다. 위치: (11222.299235051656, 3570.1721242365434), 생성 시간: 22779, 사망 시간: [2138.70247399]
# 환자 71의 eta: 945.9700357652797, etaw: 945.9700357652797
# Time: 22816
# 환자 68가 병원 3에 도착했습니다.
# 환자 68가 병원 3의 1번째 환자가 되었습니다.
# 환자 68의 치료 시간은 [2863.45994385]입니다.
# Time: 22955
# 환자 72가 생성되었습니다. 위치: (11209.7495592123, 3553.783496547115), 생성 시간: 22955, 사망 시간: [1856.09900445]
# 환자 72의 eta: 1159.446883994542, etaw: 11159.446883994542
# Time: 23150
# 환자 73가 생성되었습니다. 위치: (11226.418260796952, 3574.1908566642114), 생성 시간: 23150, 사망 시간: [3005.67328103]
# 환자 73의 eta: 287.116942594187, etaw: 18287.116942594188
# Time: 23296
# 환자 74가 생성되었습니다. 위치: (11209.102778096723, 3557.542627417085), 생성 시간: 23296, 사망 시간: [2645.29635824]
# 환자 74의 eta: 341.6072684183568, etaw: 10341.607268418356
# Time: 23343
# 환자 69가 병원 1에 도착했습니다.
# 환자 69가 병원 1의 2번째 환자가 되었습니다.
# 환자 69의 치료 시간은 [2863.45994385]입니다.
# Time: 23385
# 환자 70가 병원 3에 도착했습니다.
# 환자 70가 병원 3의 2번째 환자가 되었습니다.
# 환자 70의 치료 시간은 [2863.45994385]입니다.
# Time: 23433
# 환자 73가 병원 27에 도착했습니다.
# 환자 73가 병원 27의 2번째 환자가 되었습니다.
# 환자 73의 치료 시간은 [5154.22789893]입니다.
# Time: 23457
# 환자 75가 생성되었습니다. 위치: (11213.505559429315, 3557.713368183124), 생성 시간: 23457, 사망 시간: [2152.21000079]
# 환자 75의 eta: 199.6724069826248, etaw: 199.6724069826248
# Time: 23634
# 환자 74가 병원 1에 도착했습니다.
# 환자 74가 병원 1의 3번째 환자가 되었습니다.
# 환자 74의 치료 시간은 [2863.45994385]입니다.
# Time: 23653
# 환자 75가 병원 19에 도착했습니다.
# 환자 75가 병원 19의 1번째 환자가 되었습니다.
# 환자 75의 치료 시간은 [4008.84392139]입니다.
# Time: 23660
# 환자 76가 생성되었습니다. 위치: (11203.495958648475, 3564.4084178725357), 생성 시간: 23660, 사망 시간: [3198.62455371]
# 환자 76의 eta: 759.9624665072589, etaw: 18759.96246650726
# Time: 23721
# 환자 71가 병원 0에 도착했습니다.
# 환자 71가 병원 0의 1번째 환자가 되었습니다.
# 환자 71의 치료 시간은 [2863.45994385]입니다.
# Time: 23887
# 환자 67가 병원 14에 도착했습니다.
# 환자 67가 병원 14의 2번째 환자가 되었습니다.
# 환자 67의 치료 시간은 [4008.84392139]입니다.
# Time: 24034
# 환자 54가 병원 25에서 치료를 완료했습니다.
# Time: 24110
# 환자 72가 병원 1에 도착했습니다.
# 환자 72가 병원 1의 4번째 환자가 되었습니다.
# 환자 72의 치료 시간은 [2863.45994385]입니다.
# Time: 24150
# 환자 60가 병원 1에서 치료를 완료했습니다.
# Time: 24211
# 환자 61가 병원 11에서 치료를 완료했습니다.
# Time: 24350
# 환자 56가 병원 21에서 치료를 완료했습니다.
# Time: 24416
# 환자 76가 병원 26에 도착했습니다.
# 환자 76가 병원 26의 2번째 환자가 되었습니다.
# 환자 76의 치료 시간은 [5154.22789893]입니다.
# Time: 24605
# 환자 77가 생성되었습니다. 위치: (11214.597790294973, 3571.654809017754), 생성 시간: 24605, 사망 시간: [3117.48558062]
# 환자 77의 eta: 794.5090348054576, etaw: 24694.00397141712
# Time: 24627
# 환자 78가 생성되었습니다. 위치: (11205.142802749939, 3572.561441798401), 생성 시간: 24627, 사망 시간: [2775.93443451]
# 환자 78의 eta: 2705.543140110988, etaw: 26605.038076722652
# Time: 24787
# 환자 79가 생성되었습니다. 위치: (11209.409919114963, 3572.3821117070024), 생성 시간: 24787, 사망 시간: [2497.19403124]
# 환자 79의 eta: 1174.6594992486853, etaw: 25074.15443586035
# Time: 24812
# 환자 72가 대기중인 병원 1에서 사망했습니다.
# Time: 24862
# 환자 57가 병원 12에서 치료를 완료했습니다.
# Time: 24977
# 환자 80가 생성되었습니다. 위치: (11215.438275967846, 3557.9494409838976), 생성 시간: 24977, 사망 시간: [3003.56601153]
# 환자 80의 eta: 490.6592639533992, etaw: 490.6592639533992
# Time: 25004
# 환자 59가 병원 27에서 치료를 완료했습니다.
# Time: 25053
# 환자 70가 대기중인 병원 3에서 사망했습니다.
# Time: 25064
# 환자 58가 병원 14에서 치료를 완료했습니다.
# Time: 25185
# 환자 81가 생성되었습니다. 위치: (11213.462052974442, 3560.50621464991), 생성 시간: 25185, 사망 시간: [2399.93060564]
# 환자 81의 eta: 424.5150831104209, etaw: 14424.51508311042
# Time: 25395
# 환자 77가 병원 14에 도착했습니다.
# 환자 77가 병원 14의 2번째 환자가 되었습니다.
# 환자 77의 치료 시간은 [4008.84392139]입니다.
# Time: 25464
# 환자 80가 병원 11에 도착했습니다.
# 환자 80가 병원 11의 1번째 환자가 되었습니다.
# 환자 80의 치료 시간은 [4008.84392139]입니다.
# Time: 25605
# 환자 81가 병원 15에 도착했습니다.
# 환자 81가 병원 15의 2번째 환자가 되었습니다.
# 환자 81의 치료 시간은 [4008.84392139]입니다.
# Time: 25680
# 환자 68가 병원 3에서 치료를 완료했습니다.
# Time: 25909
# 환자 82가 생성되었습니다. 위치: (11220.622355788453, 3574.686201159748), 생성 시간: 25909, 사망 시간: [2354.54548137]
# 환자 82의 eta: 753.0723312528766, etaw: 753.0723312528766
# Time: 25942
# 환자 74가 대기중인 병원 1에서 사망했습니다.
# Time: 25958
# 환자 79가 병원 14에 도착했습니다.
# 환자 79가 병원 14의 3번째 환자가 되었습니다.
# 환자 79의 치료 시간은 [4008.84392139]입니다.
# Time: 26224
# 환자 83가 생성되었습니다. 위치: (11225.915261375483, 3573.195093432668), 생성 시간: 26224, 사망 시간: [2903.78396566]
# 환자 83의 eta: 135.72477794770077, etaw: 135.72477794770077
# Time: 26256
# 환자 65가 병원 15에서 치료를 완료했습니다.
# Time: 26318
# 환자 63가 병원 30에서 치료를 완료했습니다.
# Time: 26356
# 환자 83가 병원 17에 도착했습니다.
# 환자 83가 병원 17의 1번째 환자가 되었습니다.
# 환자 83의 치료 시간은 [4008.84392139]입니다.
# Time: 26585
# 환자 71가 병원 0에서 치료를 완료했습니다.
# Time: 26587
# 환자 84가 생성되었습니다. 위치: (11220.256542267702, 3576.8799903238273), 생성 시간: 26587, 사망 시간: [2818.42602479]
# 환자 84의 eta: 1317.0997923194486, etaw: 1317.0997923194486
# Time: 26648
# 환자 64가 병원 18에서 치료를 완료했습니다.
# Time: 26658
# 환자 82가 병원 25에 도착했습니다.
# 환자 82가 병원 25의 1번째 환자가 되었습니다.
# 환자 82의 치료 시간은 [5154.22789893]입니다.
# Time: 26857
# 환자 85가 생성되었습니다. 위치: (11218.814245025083, 3575.1387605553755), 생성 시간: 26857, 사망 시간: [2918.55536806]
# 환자 85의 eta: 1423.7677855600787, etaw: 19423.767785560078
# Time: 26859
# 환자 76가 대기중인 병원 26에서 사망했습니다.
# Time: 26985
# 환자 62가 병원 26에서 치료를 완료했습니다.
# Time: 27014
# 환자 69가 병원 1에서 치료를 완료했습니다.
# Time: 27087
# 환자 86가 생성되었습니다. 위치: (11217.028038462146, 3566.02087668978), 생성 시간: 27087, 사망 시간: [2413.17342248]
# 환자 86의 eta: 209.69548441930692, etaw: 209.69548441930692
# Time: 27103
# 환자 87가 생성되었습니다. 위치: (11223.750681165418, 3575.9688409734813), 생성 시간: 27103, 사망 시간: [2986.89578384]
# 환자 87의 eta: 786.3020166351891, etaw: 18786.30201663519
# Time: 27285
# 환자 79가 대기중인 병원 14에서 사망했습니다.
# Time: 27293
# 환자 86가 병원 5에 도착했습니다.
# 환자 86가 병원 5의 1번째 환자가 되었습니다.
# 환자 86의 치료 시간은 [2863.45994385]입니다.
# Time: 27328
# 환자 78가 병원 14에 도착했습니다.
# 환자 78가 병원 14의 3번째 환자가 되었습니다.
# 환자 78의 치료 시간은 [4008.84392139]입니다.
# Time: 27403
# 환자 78가 대기중인 병원 14에서 사망했습니다.
# Time: 27424
# 환자 88가 생성되었습니다. 위치: (11202.997912864608, 3562.447476479485), 생성 시간: 27424, 사망 시간: [2950.28724268]
# 환자 88의 eta: 1134.894881876407, etaw: 1134.894881876407
# Time: 27662
# 환자 75가 병원 19에서 치료를 완료했습니다.
# Time: 27723
# 환자 77가 대기중인 병원 14에서 사망했습니다.
# Time: 27771
# 환자 66가 병원 23에서 치료를 완료했습니다.
# Time: 27820
# 환자 89가 생성되었습니다. 위치: (11224.852863091659, 3557.9113620388125), 생성 시간: 27820, 사망 시간: [2968.61632479]
# 환자 89의 eta: 390.85664376149737, etaw: 390.85664376149737
# Time: 27885
# 환자 87가 병원 25에 도착했습니다.
# 환자 87가 병원 25의 2번째 환자가 되었습니다.
# 환자 87의 치료 시간은 [5154.22789893]입니다.
# Time: 27900
# 환자 84가 병원 25에 도착했습니다.
# 환자 84가 병원 25의 3번째 환자가 되었습니다.
# 환자 84의 치료 시간은 [5154.22789893]입니다.
# Time: 27998
# 환자 90가 생성되었습니다. 위치: (11216.750693609481, 3564.3532135943487), 생성 시간: 27998, 사망 시간: [2996.33933383]
# 환자 90의 eta: 439.55999699833154, etaw: 10439.559996998332
# Time: 28200
# 환자 91가 생성되었습니다. 위치: (11223.241082123539, 3564.7033489517507), 생성 시간: 28200, 사망 시간: [3025.98622665]
# 환자 91의 eta: 291.0716140061119, etaw: 291.0716140061119
# Time: 28207
# 환자 89가 병원 9에 도착했습니다.
# 환자 89가 병원 9의 1번째 환자가 되었습니다.
# 환자 89의 치료 시간은 [2863.45994385]입니다.
# Time: 28277
# 환자 85가 병원 25에 도착했습니다.
# 환자 85가 병원 25의 4번째 환자가 되었습니다.
# 환자 85의 치료 시간은 [5154.22789893]입니다.
# Time: 28341
# 환자 92가 생성되었습니다. 위치: (11208.835855398087, 3549.808384765467), 생성 시간: 28341, 사망 시간: [2101.37403134]
# 환자 92의 eta: 2616.7586341798365, etaw: 2616.7586341798365
# Time: 28433
# 환자 90가 병원 5에 도착했습니다.
# 환자 90가 병원 5의 2번째 환자가 되었습니다.
# 환자 90의 치료 시간은 [2863.45994385]입니다.
# Time: 28440
# 환자 93가 생성되었습니다. 위치: (11208.83803449961, 3562.154055693799), 생성 시간: 28440, 사망 시간: [2700.70691363]
# 환자 93의 eta: 430.37034660718615, etaw: 430.37034660718615
# Time: 28448
# 환자 94가 생성되었습니다. 위치: (11219.230303381235, 3574.3162826848834), 생성 시간: 28448, 사망 시간: [2984.9468019]
# 환자 94의 eta: 1226.081492586949, etaw: 55226.08149258695
# Time: 28460
# 환자 95가 생성되었습니다. 위치: (11220.398803597549, 3574.1906764215105), 생성 시간: 28460, 사망 시간: [2950.75803737]
# 환자 95의 eta: 803.567410754555, etaw: 54803.56741075456
# Time: 28487
# 환자 91가 병원 4에 도착했습니다.
# 환자 91가 병원 4의 1번째 환자가 되었습니다.
# 환자 91의 치료 시간은 [2863.45994385]입니다.
# Time: 28555
# 환자 88가 병원 26에 도착했습니다.
# 환자 88가 병원 26의 1번째 환자가 되었습니다.
# 환자 88의 치료 시간은 [5154.22789893]입니다.
# Time: 28866
# 환자 93가 병원 3에 도착했습니다.
# 환자 93가 병원 3의 1번째 환자가 되었습니다.
# 환자 93의 치료 시간은 [2863.45994385]입니다.
# Time: 29073
# 환자 67가 병원 14에서 치료를 완료했습니다.
# Time: 29181
# 환자 96가 생성되었습니다. 위치: (11212.812371935905, 3551.8222797390263), 생성 시간: 29181, 사망 시간: [2761.75970916]
# 환자 96의 eta: 1619.9797641545556, etaw: 1619.9797641545556
# Time: 29259
# 환자 95가 병원 25에 도착했습니다.
# 환자 95가 병원 25의 5번째 환자가 되었습니다.
# 환자 95의 치료 시간은 [5154.22789893]입니다.
# Time: 29406
# 환자 84가 대기중인 병원 25에서 사망했습니다.
# Time: 29473
# 환자 80가 병원 11에서 치료를 완료했습니다.
# Time: 29567
# 환자 97가 생성되었습니다. 위치: (11204.36407804027, 3571.233315064019), 생성 시간: 29567, 사망 시간: [2304.71384536]
# 환자 97의 eta: 2560.727726838338, etaw: 20560.727726838337
# Time: 29670
# 환자 94가 병원 25에 도착했습니다.
# 환자 94가 병원 25의 5번째 환자가 되었습니다.
# 환자 94의 치료 시간은 [5154.22789893]입니다.
# Time: 29776
# 환자 85가 대기중인 병원 25에서 사망했습니다.
# Time: 29893
# 환자 98가 생성되었습니다. 위치: (11217.082724566037, 3574.1355324258316), 생성 시간: 29893, 사망 시간: [2713.90037808]
# 환자 98의 eta: 1674.4596347984966, etaw: 1674.4596347984966
# Time: 29965
# 환자 99가 생성되었습니다. 위치: (11210.92282573289, 3558.891991320559), 생성 시간: 29965, 사망 시간: [2260.39673625]
# 환자 99의 eta: 743.4663633040237, etaw: 743.4663633040237
# Time: 30090
# 환자 87가 대기중인 병원 25에서 사망했습니다.
# Time: 30157
# 환자 86가 병원 5에서 치료를 완료했습니다.
# Time: 30159
# 환자 73가 병원 27에서 치료를 완료했습니다.
# Time: 30172
# 환자 100가 생성되었습니다. 위치: (11219.20852815244, 3565.4253382019024), 생성 시간: 30172, 사망 시간: [2128.26687927]
# 환자 100의 eta: 127.63584251238491, etaw: 127.63584251238491
# Time: 30265
# 환자 81가 병원 15에서 치료를 완료했습니다.
# Time: 30296
# 환자 100가 병원 28에 도착했습니다.
# 환자 100가 병원 28의 1번째 환자가 되었습니다.
# 환자 100의 치료 시간은 [5154.22789893]입니다.
# Time: 30365
# 환자 83가 병원 17에서 치료를 완료했습니다.
# Time: 30443
# 환자 92가 사망했습니다.
# Time: 30704
# 환자 99가 병원 30에 도착했습니다.
# 환자 99가 병원 30의 1번째 환자가 되었습니다.
# 환자 99의 치료 시간은 [5154.22789893]입니다.
# Time: 30797
# 환자 96가 병원 24에 도착했습니다.
# 환자 96가 병원 24의 1번째 환자가 되었습니다.
# 환자 96의 치료 시간은 [5154.22789893]입니다.
# Time: 30857
# 환자 101가 생성되었습니다. 위치: (11206.747952696707, 3566.6458104253607), 생성 시간: 30857, 사망 시간: [2339.4299085]
# 환자 101의 eta: 963.570082509087, etaw: 18963.570082509086
# Time: 31071
# 환자 89가 병원 9에서 치료를 완료했습니다.
# Time: 31351
# 환자 91가 병원 4에서 치료를 완료했습니다.
# Time: 31411
# 환자 95가 대기중인 병원 25에서 사망했습니다.
# Time: 31430
# 환자 102가 생성되었습니다. 위치: (11220.23230829438, 3572.857940682807), 생성 시간: 31430, 사망 시간: [3264.8500367]
# 환자 102의 eta: 970.8835771104659, etaw: 31698.805638468322
# Time: 31433
# 환자 94가 대기중인 병원 25에서 사망했습니다.
# Time: 31563
# 환자 98가 병원 14에 도착했습니다.
# 환자 98가 병원 14의 1번째 환자가 되었습니다.
# 환자 98의 치료 시간은 [4008.84392139]입니다.
# Time: 31724
# 환자 103가 생성되었습니다. 위치: (11228.577070151585, 3567.7682342578987), 생성 시간: 31724, 사망 시간: [2248.60584251]
# 환자 103의 eta: 949.6440452501455, etaw: 949.6440452501455
# Time: 31730
# 환자 93가 병원 3에서 치료를 완료했습니다.
# Time: 31813
# 환자 82가 병원 25에서 치료를 완료했습니다.
# Time: 31816
# 환자 104가 생성되었습니다. 위치: (11211.623475099346, 3550.3497316970775), 생성 시간: 31816, 사망 시간: [2729.18484976]
# 환자 104의 eta: 2265.391860911681, etaw: 20265.39186091168
# Time: 31816
# 환자 101가 병원 26에 도착했습니다.
# 환자 101가 병원 26의 2번째 환자가 되었습니다.
# 환자 101의 치료 시간은 [5154.22789893]입니다.
# Time: 31872
# 환자 97가 사망했습니다.
# Time: 32068
# 환자 105가 생성되었습니다. 위치: (11225.834177845318, 3562.5095069499853), 생성 시간: 32068, 사망 시간: [3200.016142]
# 환자 105의 eta: 219.9793337592543, etaw: 219.9793337592543
# Time: 32205
# 환자 106가 생성되었습니다. 위치: (11204.288748624578, 3563.453769201941), 생성 시간: 32205, 사망 시간: [2767.17329375]
# 환자 106의 eta: 548.0122298675977, etaw: 31275.93429122545
# Time: 32284
# 환자 105가 병원 6에 도착했습니다.
# 환자 105가 병원 6의 1번째 환자가 되었습니다.
# 환자 105의 치료 시간은 [2863.45994385]입니다.
# Time: 32397
# 환자 102가 병원 25에 도착했습니다.
# 환자 102가 병원 25의 1번째 환자가 되었습니다.
# 환자 102의 치료 시간은 [5154.22789893]입니다.
# Time: 32455
# 환자 107가 생성되었습니다. 위치: (11219.370395537404, 3567.690205414621), 생성 시간: 32455, 사망 시간: [2696.81608033]
# 환자 107의 eta: 412.7049967082223, etaw: 412.7049967082223
# Time: 32670
# 환자 103가 병원 20에 도착했습니다.
# 환자 103가 병원 20의 1번째 환자가 되었습니다.
# 환자 103의 치료 시간은 [5154.22789893]입니다.
# Time: 32749
# 환자 106가 병원 26에 도착했습니다.
# 환자 106가 병원 26의 3번째 환자가 되었습니다.
# 환자 106의 치료 시간은 [5154.22789893]입니다.
# Time: 32864
# 환자 107가 병원 2에 도착했습니다.
# 환자 107가 병원 2의 1번째 환자가 되었습니다.
# 환자 107의 치료 시간은 [2863.45994385]입니다.
# Time: 33021
# 환자 90가 병원 5에서 치료를 완료했습니다.
# Time: 33197
# 환자 101가 대기중인 병원 26에서 사망했습니다.
# Time: 33710
# 환자 88가 병원 26에서 치료를 완료했습니다.
# Time: 33848
# 환자 108가 생성되었습니다. 위치: (11210.862657737873, 3570.208748003908), 생성 시간: 33848, 사망 시간: [2867.05914046]
# 환자 108의 eta: 1106.7537652976225, etaw: 15106.753765297623
# Time: 33863
# 환자 109가 생성되었습니다. 위치: (11210.729052435116, 3568.1649289181737), 생성 시간: 33863, 사망 시간: [2514.49713641]
# 환자 109의 eta: 1775.7369707859752, etaw: 15775.736970785976
# Time: 34067
# 환자 110가 생성되었습니다. 위치: (11228.827266370678, 3552.242297480576), 생성 시간: 34067, 사망 시간: [2968.99074517]
# 환자 110의 eta: 1619.3709935381687, etaw: 1619.3709935381687
# Time: 34077
# 환자 104가 병원 24에 도착했습니다.
# 환자 104가 병원 24의 2번째 환자가 되었습니다.
# 환자 104의 치료 시간은 [5154.22789893]입니다.
# Time: 34185
# 환자 111가 생성되었습니다. 위치: (11222.692995281572, 3555.922397930469), 생성 시간: 34185, 사망 시간: [3232.80683176]
# 환자 111의 eta: 671.368275088233, etaw: 671.368275088233
# Time: 34248
# 환자 112가 생성되었습니다. 위치: (11212.384180884745, 3559.129141738717), 생성 시간: 34248, 사망 시간: [2303.82053293]
# 환자 112의 eta: 297.39633485982904, etaw: 297.39633485982904
# Time: 34541
# 환자 112가 병원 22에 도착했습니다.
# 환자 112가 병원 22의 1번째 환자가 되었습니다.
# 환자 112의 치료 시간은 [5154.22789893]입니다.
# Time: 34546
# 환자 104가 대기중인 병원 24에서 사망했습니다.
# Time: 34798
# 환자 113가 생성되었습니다. 위치: (11219.534144065656, 3567.3184209199967), 생성 시간: 34798, 사망 시간: [925.96490784]
# 환자 113의 eta: 268.62143191793996, etaw: 10268.62143191794
# Time: 34852
# 환자 111가 병원 9에 도착했습니다.
# 환자 111가 병원 9의 1번째 환자가 되었습니다.
# 환자 111의 치료 시간은 [2863.45994385]입니다.
# Time: 34896
# 환자 114가 생성되었습니다. 위치: (11223.541153915796, 3565.3052876724746), 생성 시간: 34896, 사망 시간: [3073.34203643]
# 환자 114의 eta: 331.14776497957155, etaw: 331.14776497957155
# Time: 34951
# 환자 108가 병원 14에 도착했습니다.
# 환자 108가 병원 14의 2번째 환자가 되었습니다.
# 환자 108의 치료 시간은 [4008.84392139]입니다.
# Time: 35063
# 환자 113가 병원 2에 도착했습니다.
# 환자 113가 병원 2의 2번째 환자가 되었습니다.
# 환자 113의 치료 시간은 [2863.45994385]입니다.
# Time: 35148
# 환자 105가 병원 6에서 치료를 완료했습니다.
# Time: 35223
# 환자 114가 병원 4에 도착했습니다.
# 환자 114가 병원 4의 1번째 환자가 되었습니다.
# 환자 114의 치료 시간은 [2863.45994385]입니다.
# Time: 35451
# 환자 100가 병원 28에서 치료를 완료했습니다.
# Time: 35572
# 환자 98가 병원 14에서 치료를 완료했습니다.
# Time: 35635
# 환자 109가 병원 14에 도착했습니다.
# 환자 109가 병원 14의 2번째 환자가 되었습니다.
# 환자 109의 치료 시간은 [4008.84392139]입니다.
# Time: 35682
# 환자 110가 병원 8에 도착했습니다.
# 환자 110가 병원 8의 1번째 환자가 되었습니다.
# 환자 110의 치료 시간은 [2863.45994385]입니다.
# Time: 35724
# 환자 113가 대기중인 병원 2에서 사망했습니다.
# Time: 35728
# 환자 107가 병원 2에서 치료를 완료했습니다.
# Time: 35859
# 환자 99가 병원 30에서 치료를 완료했습니다.
# Time: 35952
# 환자 96가 병원 24에서 치료를 완료했습니다.

# %%
patient_generate_points
# Out:
# [171,
#  277,
#  854,
#  930,
#  1141,
#  1801,
#  2036,
#  3563,
#  3695,
#  4230,
#  4436,
#  4508,
#  4988,
#  5269,
#  5353,
#  5425,
#  5831,
#  5844,
#  6130,
#  6143,
#  6263,
#  6265,
#  7010,
#  7564,
#  7816,
#  7987,
#  8282,
#  8738,
#  8923,
#  9300,
#  9359,
#  9932,
#  10156,
#  10164,
#  10864,
#  11218,
#  11285,
#  11402,
#  11548,
#  11632,
#  11799,
#  12173,
#  12528,
#  12613,
#  12720,
#  13133,
#  13409,
#  13440,
#  13667,
#  13904,
#  14263,
#  14581,
#  14642,
#  14875,
#  15022,
#  15575,
#  16132,
#  16211,
#  16215,
#  17136,
#  17202,
#  17496,
#  17672,
#  17788,
#  18198,
#  19643,
#  19686,
#  20023,
#  20260,
#  20276,
#  20380,
#  20457,
#  20647,
#  20823,
#  21018,
#  21164,
#  21325,
#  21528,
#  21618,
#  21640,
#  21800,
#  23162,
#  23202,
#  24411,
#  24767,
#  25042,
#  25252,
#  25412,
#  25442,
#  26311,
#  26632,
#  27080,
#  27147,
#  27174,
#  27466,
#  28193,
#  28385,
#  28716,
#  28816,
#  29121,
#  29761,
#  29784,
#  29979,
#  30103,
#  30287,
#  30521,
#  30815,
#  31165,
#  31188,
#  31325,
#  31575,
#  32968,
#  32983,
#  33187,
#  33305,
#  33368,
#  33918,
#  34296,
#  34372,
#  34498,
#  34560,
#  34682,
#  34935,
#  35565]
